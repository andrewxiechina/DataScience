# %% [markdown]
# This is a copy of:
# https://www.kaggle.com/ash316/novice-to-grandmaster/data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
response=pd.read_csv('../input/multipleChoiceResponses.csv',encoding='ISO-8859-1')
response.head()
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (31,83,86,87,98,99,109,116,123,124,127,129,130,164) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                         GenderSelect        Country   Age  \
# 0  Non-binary, genderqueer, or gender non-conforming            NaN   NaN
# 1                                             Female  United States  30.0
# 2                                               Male         Canada  28.0
# 3                                               Male  United States  56.0
# 4                                               Male         Taiwan  38.0
#
#                                     EmploymentStatus StudentStatus  \
# 0                                 Employed full-time           NaN
# 1                 Not employed, but looking for work           NaN
# ...

# %% [markdown]
#  # Gender Split

# %%
plt.subplots(figsize=(22,12))
sns.countplot(y=response["GenderSelect"], order=response["GenderSelect"].value_counts().index)
plt.show()

# %% [markdown]
# # Respondents by Country

# %%
plt.subplots(figsize=(22,15))
sns.countplot(y=response["Country"], order=response["Country"].value_counts()[:15].index)
plt.title('Top 15 Countries by number of respondents', size="40")
plt.ylabel('')
plt.xlabel('')
plt.show()

# %%
import squarify
plt.subplots(figsize=(22,15))
squarify.plot(sizes = country_count.values, label = country_count.index, color=sns.color_palette('RdYlGn_r',52))
plt.show()

# %%
sns.palplot(sns.color_palette('RdYlGn_r',52))

# %% [markdown]
# # Compensation

# %%
salary = response[["CompensationAmount", "CompensationCurrency"]]
salary = salary.dropna(how='any')
salary["CompensationAmount"] = pd.to_numeric(salary['CompensationAmount'].str.replace(',','').str.replace('-',''))
plt.subplots(figsize=(15,8))
salary=salary[salary['CompensationCurrency']== "USD"]
salary = salary.dropna(how='any')
salary = salary[salary['CompensationAmount'] > 1000]
salary = salary[salary['CompensationAmount'] < 300000]
sns.distplot(salary['CompensationAmount'])
plt.title('Salary Distribution',size=15)
plt.show()

# %%
salary = response[["CompensationAmount", "CompensationCurrency"]]
salary = salary.dropna(how='any')
salary["CompensationAmount"] = pd.to_numeric(salary['CompensationAmount'].str.replace(',','').str.replace('-',''))
plt.subplots(figsize=(15,8))
salary=salary[salary['CompensationCurrency']== "EUR"]
salary = salary.dropna(how='any')
salary = salary[salary['CompensationAmount'] > 1000]
salary = salary[salary['CompensationAmount'] < 150000]
sns.distplot(salary['CompensationAmount'])
plt.title('Salary Distribution',size=15)
plt.show()

# %% [markdown]
# # Age

# %%
plt.subplots(figsize=(15,8))
sns.distplot(response[response["Age"] < 66][response["Age"] > 15]["Age"].dropna())
plt.title("Age Distribution")
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
